# %% [markdown]
# <a href="https://colab.research.google.com/github/rizko77/AI_Song_Cover/blob/main/AI_Song_Cover_SOVITS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title 0. Check GPU
# !nvidia-smi
# Out:
# Sun Mar 22 20:25:20 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   33C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
#@title Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#@title 1. Install Library for Youtube WAV Download
# !pip install yt_dlp
# !pip install ffmpeg
# !mkdir youtubeaudio
# Out:
# Collecting yt_dlp
#   Downloading yt_dlp-2026.3.17-py3-none-any.whl.metadata (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.3/182.3 kB 6.9 MB/s eta 0:00:00
# Downloading yt_dlp-2026.3.17-py3-none-any.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 72.2 MB/s eta 0:00:00
# Installing collected packages: yt_dlp
# Successfully installed yt_dlp-2026.3.17
# Collecting ffmpeg
#   Downloading ffmpeg-1.4.tar.gz (5.1 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: ffmpeg
#   Building wheel for ffmpeg (setup.py) ... done
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6083 sha256=c09bfa14fb73cd9ab53d91ae60f7d05d7782bbc2f2f2b102fe33d239d8d291df
#   Stored in directory: /root/.cache/pip/wheels/26/21/0c/c26e09dff860a9071683e279445262346e008a9a1d2142c4ad
# Successfully built ffmpeg
# Installing collected packages: ffmpeg
# Successfully installed ffmpeg-1.4

# %%
#@title Download Youtube WAV
from __future__ import unicode_literals
import yt_dlp
import ffmpeg
import sys

ydl_opts = {
    'format': 'bestaudio/best',
#    'outtmpl': 'output.%(ext)s',
    'postprocessors': [{
        'key': 'FFmpegExtractAudio',
        'preferredcodec': 'wav',
    }],
    "outtmpl": 'youtubeaudio/audio',  # this is where you can edit how you'd like the filenames to be formatted
}
def download_from_url(url):
    ydl.download([url])
    # stream = ffmpeg.input('output.m4a')
    # stream = ffmpeg.output(stream, 'output.wav')


with yt_dlp.YoutubeDL(ydl_opts) as ydl:
      url = "https://youtu.be/trQAmuvlb1Y?si=QGjcEfhoHYzDj-OF" #@param {type:"string"}
      download_from_url(url)
# Out:
# [youtube] Extracting URL: https://youtu.be/trQAmuvlb1Y?si=QGjcEfhoHYzDj-OF
# [youtube] trQAmuvlb1Y: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] trQAmuvlb1Y: Downloading android vr player API JSON
# [info] trQAmuvlb1Y: Downloading 1 format(s): 251
# [download] Destination: youtubeaudio/audio
# [download] 100% of    3.42MiB in 00:00:00 at 7.61MiB/s
# [ExtractAudio] Destination: youtubeaudio/audio.wav
# Deleting original file youtubeaudio/audio (pass -k to keep)

# %%
#@title 2. Install Demucs for Separating Audio
# !python3 -m pip install -U demucs
# Out:
# Collecting demucs
#   Downloading demucs-4.0.1.tar.gz (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 24.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting dora-search (from demucs)
#   Downloading dora_search-0.1.12.tar.gz (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.1/87.1 kB 10.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from demucs) (0.8.2)
# Collecting julius>=0.2.3 (from demucs)
#   Downloading julius-0.2.7.tar.gz (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 6.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting lameenc>=1.2 (from demucs)
#   Downloading lameenc-1.8.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (10.0 kB)
# Collecting openunmix (from demucs)
#   Downloading openunmix-1.3.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from demucs) (6.0.3)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from demucs) (2.10.0+cu128)
# Requirement already satisfied: torchaudio>=0.8 in /usr/local/lib/python3.12/dist-packages (from demucs) (2.10.0+cu128)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from demucs) (4.67.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->demucs) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.8.1->demucs) (1.4.3)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.12/dist-packages (from dora-search->demucs) (2.3.0)
# Collecting retrying (from dora-search->demucs)
#   Downloading retrying-1.4.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting submitit (from dora-search->demucs)
#   Downloading submitit-1.5.4-py3-none-any.whl.metadata (7.4 kB)
# Collecting treetable (from dora-search->demucs)
#   Downloading treetable-0.2.6-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from openunmix->demucs) (2.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.1->demucs) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.1->demucs) (3.0.3)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf->dora-search->demucs) (4.9.3)
# Requirement already satisfied: cloudpickle>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from submitit->dora-search->demucs) (3.1.2)
# Downloading lameenc-1.8.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (249 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.3/249.3 kB 31.8 MB/s eta 0:00:00
# Downloading openunmix-1.3.0-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.0/40.0 kB 4.3 MB/s eta 0:00:00
# Downloading retrying-1.4.2-py3-none-any.whl (10 kB)
# Downloading submitit-1.5.4-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 kB 9.8 MB/s eta 0:00:00
# Downloading treetable-0.2.6-py3-none-any.whl (7.4 kB)
# Building wheels for collected packages: demucs, julius, dora-search
#   Building wheel for demucs (setup.py) ... done
#   Created wheel for demucs: filename=demucs-4.0.1-py3-none-any.whl size=78388 sha256=f5da55c5bb9c1317fd617b4cf7bee32b0f2b9ca5adf57cd0acf85da05b75e0dd
#   Stored in directory: /root/.cache/pip/wheels/1b/0c/20/a3b3daa1f9b65c8b0445729f94740ec335d0f86f1066c5c414
#   Building wheel for julius (setup.py) ... done
#   Created wheel for julius: filename=julius-0.2.7-py3-none-any.whl size=21870 sha256=c7342456c62f4bb6f28a92f2ff25e07af187c6b38ef3a31397293292c8bad529
#   Stored in directory: /root/.cache/pip/wheels/de/c1/ca/544dafe48401e8e2e17064dfe465a390fca9e8720ffa12e744
#   Building wheel for dora-search (pyproject.toml) ... done
#   Created wheel for dora-search: filename=dora_search-0.1.12-py3-none-any.whl size=75195 sha256=1e1201e382bffde91e2af9a8b457ce65d0893655c08dfe9768e648f682dbd297
#   Stored in directory: /root/.cache/pip/wheels/55/40/4c/3478187386b56625ab5aa8a9070ff1eea704ddb27d15abe73f
# Successfully built demucs julius dora-search
# Installing collected packages: lameenc, treetable, submitit, retrying, julius, dora-search, openunmix, demucs
# Successfully installed demucs-4.0.1 dora-search-0.1.12 julius-0.2.7 lameenc-1.8.2 openunmix-1.3.0 retrying-1.4.2 submitit-1.5.4 treetable-0.2.6

# %%
#@title Separate Vocal and Instrument/Noise using Demucs
import subprocess
AUDIO_INPUT = "/content/youtubeaudio/audio.wav" #@param {type:"string"}

command = f"demucs --two-stems=vocals {AUDIO_INPUT}"
result = subprocess.run(command.split(), stdout=subprocess.PIPE)
print(result.stdout.decode())
# Out:
# Important: the default model was recently changed to `htdemucs` the latest Hybrid Transformer Demucs model. In some cases, this model can actually perform worse than previous models. To get back the old default model use `-n mdx_extra_q`.
# Downloading: "https://dl.fbaipublicfiles.com/demucs/hybrid_transformer/955717e8-8726e21a.th" to /root/.cache/torch/hub/checkpoints/955717e8-8726e21a.th
# Selected model is a bag of 1 models. You will see that many progress bars per track.
# Separated tracks will be stored in /content/separated/htdemucs
# Separating track /content/youtubeaudio/audio.wav

# %%
#@title 3. Split The Audio into Smaller Duration Before Training
#@markdown don't put space on speaker name
SPEAKER_NAME = "Kokona" #@param {type:"string"}
# !mkdir -p dataset_raw/{SPEAKER_NAME}

# %%
from scipy.io import wavfile
import os
import numpy as np
import argparse
from tqdm import tqdm
import json

from datetime import datetime, timedelta

# Utility functions

def GetTime(video_seconds):

    if (video_seconds < 0) :
        return 00

    else:
        sec = timedelta(seconds=float(video_seconds))
        d = datetime(1,1,1) + sec

        instant = str(d.hour).zfill(2) + ':' + str(d.minute).zfill(2) + ':' + str(d.second).zfill(2) + str('.001')

        return instant

def GetTotalTime(video_seconds):

    sec = timedelta(seconds=float(video_seconds))
    d = datetime(1,1,1) + sec
    delta = str(d.hour) + ':' + str(d.minute) + ":" + str(d.second)

    return delta

def windows(signal, window_size, step_size):
    if type(window_size) is not int:
        raise AttributeError("Window size must be an integer.")
    if type(step_size) is not int:
        raise AttributeError("Step size must be an integer.")
    for i_start in range(0, len(signal), step_size):
        i_end = i_start + window_size
        if i_end >= len(signal):
            break
        yield signal[i_start:i_end]

def energy(samples):
    return np.sum(np.power(samples, 2.)) / float(len(samples))

def rising_edges(binary_signal):
    previous_value = 0
    index = 0
    for x in binary_signal:
        if x and not previous_value:
            yield index
        previous_value = x
        index += 1

'''
Last Acceptable Values

min_silence_length = 0.3
silence_threshold = 1e-3
step_duration = 0.03/10

'''
# Change the arguments and the input file here
input_file = "/content/separated/htdemucs/audio/vocals.wav" #@param {type:"string"}
output_dir = f"/content/dataset_raw/{SPEAKER_NAME}"
min_silence_length = 0.6  # The minimum length of silence at which a split may occur [seconds]. Defaults to 3 seconds.
silence_threshold = 1e-4  # The energy level (between 0.0 and 1.0) below which the signal is regarded as silent.
step_duration = 0.03/10   # The amount of time to step forward in the input file after calculating energy. Smaller value = slower, but more accurate silence detection. Larger value = faster, but might miss some split opportunities. Defaults to (min-silence-length / 10.).


input_filename = input_file
window_duration = min_silence_length
if step_duration is None:
    step_duration = window_duration / 10.
else:
    step_duration = step_duration

output_filename_prefix = os.path.splitext(os.path.basename(input_filename))[0]
dry_run = False

print("Splitting {} where energy is below {}% for longer than {}s.".format(
    input_filename,
    silence_threshold * 100.,
    window_duration
    )
)

# Read and split the file

sample_rate, samples = input_data=wavfile.read(filename=input_filename, mmap=True)

max_amplitude = np.iinfo(samples.dtype).max
print(max_amplitude)

max_energy = energy([max_amplitude])
print(max_energy)

window_size = int(window_duration * sample_rate)
step_size = int(step_duration * sample_rate)

signal_windows = windows(
    signal=samples,
    window_size=window_size,
    step_size=step_size
)

window_energy = (energy(w) / max_energy for w in tqdm(
    signal_windows,
    total=int(len(samples) / float(step_size))
))

window_silence = (e > silence_threshold for e in window_energy)

cut_times = (r * step_duration for r in rising_edges(window_silence))

# This is the step that takes long, since we force the generators to run.
print("Finding silences...")
cut_samples = [int(t * sample_rate) for t in cut_times]
cut_samples.append(-1)

cut_ranges = [(i, cut_samples[i], cut_samples[i+1]) for i in range(len(cut_samples) - 1)]

video_sub = {str(i) : [str(GetTime(((cut_samples[i])/sample_rate))),
                       str(GetTime(((cut_samples[i+1])/sample_rate)))]
             for i in range(len(cut_samples) - 1)}

for i, start, stop in tqdm(cut_ranges):
    output_file_path = "{}_{:03d}.wav".format(
        os.path.join(output_dir, output_filename_prefix),
        i
    )
    if not dry_run:
        print("Writing file {}".format(output_file_path))
        wavfile.write(
            filename=output_file_path,
            rate=sample_rate,
            data=samples[start:stop]
        )
    else:
        print("Not writing file {}".format(output_file_path))

with open (output_dir+'\\'+output_filename_prefix+'.json', 'w') as output:
    json.dump(video_sub, output)
# Out:
# Splitting /content/separated/htdemucs/audio/vocals.wav where energy is below 0.01% for longer than 0.6s.
# 32767
# 1073676289.0
#   0%|          | 19/74224 [00:00<06:36, 187.37it/s]
# Finding silences...
# 100%|█████████▉| 74025/74224 [05:14<00:00, 235.20it/s]
# 100%|██████████| 21/21 [00:00<00:00, 876.91it/s]
# Writing file /content/dataset_raw/Kokona/vocals_000.wav
# Writing file /content/dataset_raw/Kokona/vocals_001.wav
# Writing file /content/dataset_raw/Kokona/vocals_002.wav
# Writing file /content/dataset_raw/Kokona/vocals_003.wav
# Writing file /content/dataset_raw/Kokona/vocals_004.wav
# Writing file /content/dataset_raw/Kokona/vocals_005.wav
# Writing file /content/dataset_raw/Kokona/vocals_006.wav
# Writing file /content/dataset_raw/Kokona/vocals_007.wav
# Writing file /content/dataset_raw/Kokona/vocals_008.wav
# Writing file /content/dataset_raw/Kokona/vocals_009.wav
# Writing file /content/dataset_raw/Kokona/vocals_010.wav
# Writing file /content/dataset_raw/Kokona/vocals_011.wav
# Writing file /content/dataset_raw/Kokona/vocals_012.wav
# Writing file /content/dataset_raw/Kokona/vocals_013.wav
# Writing file /content/dataset_raw/Kokona/vocals_014.wav
# Writing file /content/dataset_raw/Kokona/vocals_015.wav
# Writing file /content/dataset_raw/Kokona/vocals_016.wav
# Writing file /content/dataset_raw/Kokona/vocals_017.wav
# Writing file /content/dataset_raw/Kokona/vocals_018.wav
# Writing file /content/dataset_raw/Kokona/vocals_019.wav
# Writing file /content/dataset_raw/Kokona/vocals_020.wav

# %%
#@title 4. Install dependencies for Training
#@markdown makesure there are no "so-vits-svc-fork" folder on your Drive before you run this
# !pip install pyworld==0.3.2
# !python -m pip install -U pip wheel
# %pip install -U ipython
# %pip install -U so-vits-svc-fork
# !mkdir drive/MyDrive/so-vits-svc-fork
# Out:
# Collecting pyworld==0.3.2
#   Downloading pyworld-0.3.2.tar.gz (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.4/214.4 kB 9.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pyworld==0.3.2) (2.0.2)
# Requirement already satisfied: cython in /usr/local/lib/python3.12/dist-packages (from pyworld==0.3.2) (3.0.12)
# Building wheels for collected packages: pyworld
#   Building wheel for pyworld (pyproject.toml) ... done
#   Created wheel for pyworld: filename=pyworld-0.3.2-cp312-cp312-linux_x86_64.whl size=941005 sha256=d606c0193391e21694cb519971844ec22c605f71ca6b44565d4bbdfd725d612e
#   Stored in directory: /root/.cache/pip/wheels/c8/b9/af/98f6b9ad793c08fb9f90774a530a05e541426623813391193f
# Successfully built pyworld
# Installing collected packages: pyworld
# Successfully installed pyworld-0.3.2
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-26.0.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: wheel in /usr/local/lib/python3.12/dist-packages (0.46.3)
# Requirement already satisfied: packaging>=24.0 in /usr/local/lib/python3.12/dist-packages (from wheel) (26.0)
# Downloading pip-26.0.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 30.6 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-26.0.1
# Requirement already satisfied: ipython in /usr/local/lib/python3.12/dist-packages (7.34.0)
# Collecting ipython
#   Downloading ipython-9.11.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting decorator>=5.1.0 (from ipython)
#   Downloading decorator-5.2.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting ipython-pygments-lexers>=1.0.0 (from ipython)
#   Downloading ipython_pygments_lexers-1.1.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting jedi>=0.18.2 (from ipython)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from ipython) (0.2.1)
# Requirement already satisfied: pexpect>4.6 in /usr/local/lib/python3.12/dist-packages (from ipython) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /usr/local/lib/python3.12/dist-packages (from ipython) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in /usr/local/lib/python3.12/dist-packages (from ipython) (2.19.2)
# Collecting stack_data>=0.6.0 (from ipython)
#   Downloading stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting traitlets>=5.13.0 (from ipython)
#   Downloading traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.18.2->ipython) (0.8.6)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.6->ipython) (0.7.0)
# Collecting executing>=1.2.0 (from stack_data>=0.6.0->ipython)
#   Downloading executing-2.2.1-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting asttokens>=2.1.0 (from stack_data>=0.6.0->ipython)
#   Downloading asttokens-3.0.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting pure-eval (from stack_data>=0.6.0->ipython)
#   Downloading pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Downloading ipython-9.11.0-py3-none-any.whl (624 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 624.2/624.2 kB 22.6 MB/s  0:00:00
# Downloading decorator-5.2.1-py3-none-any.whl (9.2 kB)
# Downloading ipython_pygments_lexers-1.1.1-py3-none-any.whl (8.1 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 62.1 MB/s  0:00:00
# Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Downloading asttokens-3.0.1-py3-none-any.whl (27 kB)
# Downloading executing-2.2.1-py2.py3-none-any.whl (28 kB)
# Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
# Downloading pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Installing collected packages: pure-eval, traitlets, jedi, ipython-pygments-lexers, executing, decorator, asttokens, stack_data, ipython
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.7.1
#     Uninstalling traitlets-5.7.1:
#       Successfully uninstalled traitlets-5.7.1
#   Attempting uninstall: decorator
#     Found existing installation: decorator 4.4.2
#     Uninstalling decorator-4.4.2:
#       Successfully uninstalled decorator-4.4.2
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.34.0
#     Uninstalling ipython-7.34.0:
#       Successfully uninstalled ipython-7.34.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [ipython]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipython==7.34.0, but you have ipython 9.11.0 which is incompatible.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.2.1 which is incompatible.
# Successfully installed asttokens-3.0.1 decorator-5.2.1 executing-2.2.1 ipython-9.11.0 ipython-pygments-lexers-1.1.1 jedi-0.19.2 pure-eval-0.2.3 stack_data-0.6.3 traitlets-5.14.3
# Collecting so-vits-svc-fork
#   Downloading so_vits_svc_fork-4.2.30-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.12/dist-packages (from so-vits-svc-fork) (8.3.1)
# Collecting cm-time>=0.1.2 (from so-vits-svc-fork)
#   Downloading cm_time-0.1.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: fastapi>=0.116.1 in /usr/local/lib/python3.12/dist-packages (from so-vits-svc-fork) (0.135.1)
# Requirement already satisfied: librosa>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from so-vits-svc-fork) (0.11.0)
# Collecting lightning>=2.5.5 (from so-vits-svc-fork)
#   Downloading lightning-2.6.1-py3-none-any.whl.metadata (44 kB)
# Requirement already satisfied: matplotlib>=3.9.4 in /usr/local/lib/python3.12/dist-packages (from so-vits-svc-fork) (3.10.0)
# Requirement already satisfied: numpy>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from so-vits-svc-fork) (2.0.2)
# Collecting pebble>=5.1.3 (from so-vits-svc-fork)
#   Downloading pebble-5.2.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting praat-parselmouth>=0.4.6 (from so-vits-svc-fork)
#   Downloading praat_parselmouth-0.4.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.9 kB)
# Collecting psutil>=7.1.2 (from so-vits-svc-fork)
#   Downloading psutil-7.2.2-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl.metadata (22 kB)
# Collecting pysimplegui-4-foss>=4.60.4.1 (from so-vits-svc-fork)
#   Downloading PySimpleGUI_4_foss-4.60.4.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting pyworld>=0.3.5 (from so-vits-svc-fork)
#   Downloading pyworld-0.3.5.tar.gz (261 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting requests>=2.32.5 (from so-vits-svc-fork)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting rich>=14.1.0 (from so-vits-svc-fork)
#   Downloading rich-14.3.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: scipy>=1.13.1 in /usr/local/lib/python3.12/dist-packages (from so-vits-svc-fork) (1.16.3)
# Collecting sounddevice>=0.5.2 (from so-vits-svc-fork)
#   Downloading sounddevice-0.5.5-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: soundfile>=0.13.1 in /usr/local/lib/python3.12/dist-packages (from so-vits-svc-fork) (0.13.1)
# Collecting tensorboard>=2.20.0 (from so-vits-svc-fork)
#   Downloading tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting tensorboardx>=2.6.4 (from so-vits-svc-fork)
#   Downloading tensorboardx-2.6.4-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: torch>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from so-vits-svc-fork) (2.10.0+cu128)
# Requirement already satisfied: torchaudio>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from so-vits-svc-fork) (2.10.0+cu128)
# Collecting torchcrepe>=0.0.24 (from so-vits-svc-fork)
#   Downloading torchcrepe-0.0.24-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: tqdm>=4.67.1 in /usr/local/lib/python3.12/dist-packages (from so-vits-svc-fork) (4.67.3)
# Collecting tqdm-joblib>=0.0.4 (from so-vits-svc-fork)
#   Downloading tqdm_joblib-0.0.5-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: transformers>=4.56.1 in /usr/local/lib/python3.12/dist-packages (from so-vits-svc-fork) (5.0.0)
# Requirement already satisfied: starlette>=0.46.0 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.116.1->so-vits-svc-fork) (0.52.1)
# Requirement already satisfied: pydantic>=2.7.0 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.116.1->so-vits-svc-fork) (2.12.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.116.1->so-vits-svc-fork) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.116.1->so-vits-svc-fork) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.116.1->so-vits-svc-fork) (0.0.4)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.11.0->so-vits-svc-fork) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.11.0->so-vits-svc-fork) (0.60.0)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.11.0->so-vits-svc-fork) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.11.0->so-vits-svc-fork) (1.5.3)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.11.0->so-vits-svc-fork) (5.2.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.11.0->so-vits-svc-fork) (1.9.0)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.11.0->so-vits-svc-fork) (1.0.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.11.0->so-vits-svc-fork) (0.5)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.11.0->so-vits-svc-fork) (1.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from lazy_loader>=0.1->librosa>=0.11.0->so-vits-svc-fork) (26.0)
# Requirement already satisfied: PyYAML<8.0,>5.4 in /usr/local/lib/python3.12/dist-packages (from lightning>=2.5.5->so-vits-svc-fork) (6.0.3)
# Requirement already satisfied: fsspec<2028.0,>=2022.5.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2028.0,>=2022.5.0->lightning>=2.5.5->so-vits-svc-fork) (2025.3.0)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning>=2.5.5->so-vits-svc-fork)
#   Downloading lightning_utilities-0.15.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting torchmetrics<3.0,>0.7.0 (from lightning>=2.5.5->so-vits-svc-fork)
#   Downloading torchmetrics-1.9.0-py3-none-any.whl.metadata (23 kB)
# Collecting pytorch-lightning (from lightning>=2.5.5->so-vits-svc-fork)
#   Downloading pytorch_lightning-2.6.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2028.0,>=2022.5.0->lightning>=2.5.5->so-vits-svc-fork) (3.13.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (3.25.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.8.0->so-vits-svc-fork) (1.4.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.5.5->so-vits-svc-fork) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.5.5->so-vits-svc-fork) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.5.5->so-vits-svc-fork) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.5.5->so-vits-svc-fork) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.5.5->so-vits-svc-fork) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.5.5->so-vits-svc-fork) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.5.5->so-vits-svc-fork) (1.23.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.5.5->so-vits-svc-fork) (3.11)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.4->so-vits-svc-fork) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.4->so-vits-svc-fork) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.4->so-vits-svc-fork) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.4->so-vits-svc-fork) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.4->so-vits-svc-fork) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.4->so-vits-svc-fork) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.4->so-vits-svc-fork) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.0->librosa>=0.11.0->so-vits-svc-fork) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa>=0.11.0->so-vits-svc-fork) (4.9.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.7.0->fastapi>=0.116.1->so-vits-svc-fork) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.7.0->fastapi>=0.116.1->so-vits-svc-fork) (2.41.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.9.4->so-vits-svc-fork) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.5->so-vits-svc-fork) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.5->so-vits-svc-fork) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.5->so-vits-svc-fork) (2026.2.25)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=14.1.0->so-vits-svc-fork) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=14.1.0->so-vits-svc-fork) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=14.1.0->so-vits-svc-fork) (0.1.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.0->librosa>=0.11.0->so-vits-svc-fork) (3.6.0)
# Requirement already satisfied: cffi in /usr/local/lib/python3.12/dist-packages (from sounddevice>=0.5.2->so-vits-svc-fork) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi->sounddevice>=0.5.2->so-vits-svc-fork) (3.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.12/dist-packages (from starlette>=0.46.0->fastapi>=0.116.1->so-vits-svc-fork) (4.12.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.8.0->so-vits-svc-fork) (1.3.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.20.0->so-vits-svc-fork) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.20.0->so-vits-svc-fork) (1.78.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.20.0->so-vits-svc-fork) (3.10.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.20.0->so-vits-svc-fork) (5.29.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.20.0->so-vits-svc-fork) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.20.0->so-vits-svc-fork) (3.1.6)
# Collecting resampy (from torchcrepe>=0.0.24->so-vits-svc-fork)
#   Downloading resampy-0.4.3-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.56.1->so-vits-svc-fork) (1.7.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.56.1->so-vits-svc-fork) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.56.1->so-vits-svc-fork) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers>=4.56.1->so-vits-svc-fork) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.56.1->so-vits-svc-fork) (0.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=4.56.1->so-vits-svc-fork) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=4.56.1->so-vits-svc-fork) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=4.56.1->so-vits-svc-fork) (0.24.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=4.56.1->so-vits-svc-fork) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=4.56.1->so-vits-svc-fork) (0.16.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.20.0->so-vits-svc-fork) (3.0.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.56.1->so-vits-svc-fork) (1.5.4)
# Downloading so_vits_svc_fork-4.2.30-py3-none-any.whl (93 kB)
# Downloading cm_time-0.1.2-py3-none-any.whl (7.8 kB)
# Downloading lightning-2.6.1-py3-none-any.whl (853 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 853.6/853.6 kB 35.2 MB/s  0:00:00
# Downloading lightning_utilities-0.15.3-py3-none-any.whl (31 kB)
# Downloading torchmetrics-1.9.0-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 68.6 MB/s  0:00:00
# Downloading pebble-5.2.0-py3-none-any.whl (34 kB)
# Downloading praat_parselmouth-0.4.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 79.1 MB/s  0:00:00
# Downloading psutil-7.2.2-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl (155 kB)
# Downloading PySimpleGUI_4_foss-4.60.4.1-py3-none-any.whl (689 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 689.5/689.5 kB 30.1 MB/s  0:00:00
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading rich-14.3.3-py3-none-any.whl (310 kB)
# Downloading sounddevice-0.5.5-py3-none-any.whl (32 kB)
# Downloading tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 100.3 MB/s  0:00:00
# Downloading tensorboardx-2.6.4-py3-none-any.whl (87 kB)
# Downloading torchcrepe-0.0.24-py3-none-any.whl (72.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.3/72.3 MB 53.9 MB/s  0:00:01
# Downloading tqdm_joblib-0.0.5-py3-none-any.whl (1.9 kB)
# Downloading pytorch_lightning-2.6.1-py3-none-any.whl (857 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 857.3/857.3 kB 38.1 MB/s  0:00:00
# Downloading resampy-0.4.3-py3-none-any.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 83.9 MB/s  0:00:00
# Building wheels for collected packages: pyworld
#   Building wheel for pyworld (pyproject.toml) ... canceled
# ERROR: Operation cancelled by user
# ^C
# mkdir: cannot create directory ‘drive/MyDrive/so-vits-svc-fork’: File exists

# %%
#@title Automatic preprocessing
# !svc pre-resample
# Out:
# /bin/bash: line 1: svc: command not found

# %%
# !svc pre-config
# Out:
# /bin/bash: line 1: svc: command not found

# %%
#@title Copy configs file
# !cp configs/44k/config.json drive/MyDrive/so-vits-svc-fork
# Out:
# cp: cannot stat 'configs/44k/config.json': No such file or directory

# %%
F0_METHOD = "dio" #@param ["crepe", "crepe-tiny", "parselmouth", "dio", "harvest"]
# !svc pre-hubert -fm {F0_METHOD}
# Out:
# /bin/bash: line 1: svc: command not found

# %%
#@title Train
# %load_ext tensorboard
# %tensorboard --logdir drive/MyDrive/so-vits-svc-fork/logs/44k
# !svc train --model-path drive/MyDrive/so-vits-svc-fork/logs/44k

# %%
#@title 5. Inference
#@markdown remove ".wav" on AUDIO. if you facing "SVC Command not Found", install step 4 depedencies first. Don't put space of folder/file name
from IPython.display import Audio

AUDIO = "/content/separated/htdemucs/audio/vocals" #@param {type:"string"}
MODEL = "/content/drive/MyDrive/so-vits-svc-fork/logs/44k/SunoharaKokona.pth" #@param {type:"string"}
CONFIG = "/content/drive/MyDrive/so-vits-svc-fork/logs/44k/config.json" #@param {type:"string"}
#@markdown Change According to Your Voice Tone. 12 = 1 Octave | -12 = -1 Octave
PITCH = 0 #@param {type:"integer"}

# !svc infer {AUDIO}.wav -c {CONFIG} -m {MODEL} -na -t {PITCH}
# Try comment this line below if you got Runtime Error
try:
  display(Audio(f"{AUDIO}.out.wav", autoplay=True))
except Exception as e:  print("Error:", str(e))

# %%
#@title 5.1 Inference Using Pretrained Model

# %%
#@title Credit - https://huggingface.co/spaces/zomehwh/sovits-models (Diganti dengan model Alice karena Model Hololive di Private oleh yang punya)
# !mkdir so-vits-test
# !wget -N "https://huggingface.co/spaces/zomehwh/sovits-models/resolve/main/models/alice/alice.pth" -P so-vits-test/
# !wget -N "https://huggingface.co/spaces/zomehwh/sovits-models/resolve/main/models/alice/config.json" -P so-vits-test/

# %%
#@title 5.3 Combine Vocal and Instrument (Song Cover)
# !pip install pydub
from pydub import AudioSegment

VOCAL = "/content/separated/htdemucs/audio/vocals.out.wav" #@param {type:"string"}
INSTRUMENT = "/content/separated/htdemucs/audio/no_vocals.wav" #@param {type:"string"}

sound1 = AudioSegment.from_file(VOCAL)
sound2 = AudioSegment.from_file(INSTRUMENT)

combined = sound1.overlay(sound2)

combined.export("/content/FinalCover.wav", format='wav')
try:
  display(Audio(f"/content/FinalCover.wav", autoplay=True))
except Exception as e:  print("Error:", str(e))

# %%
#@title 6. Additional : Audio Recording
# !pip install ffmpeg-python

# %%
"""
To write this piece of code I took inspiration/code from a lot of places.
It was late night, so I'm not sure how much I created or just copied o.O
Here are some of the possible references:
https://blog.addpipe.com/recording-audio-in-the-browser-using-pure-html5-and-minimal-javascript/
https://stackoverflow.com/a/18650249
https://hacks.mozilla.org/2014/06/easy-audio-capture-with-the-mediarecorder-api/
https://air.ghost.io/recording-to-an-audio-file-using-html5-and-js/
https://stackoverflow.com/a/49019356
"""
from IPython.display import HTML, Audio
from google.colab.output import eval_js
from base64 import b64decode
import numpy as np
from scipy.io.wavfile import read as wav_read
import io
import ffmpeg

AUDIO_HTML = """
<script>
var my_div = document.createElement("DIV");
var my_p = document.createElement("P");
var my_btn = document.createElement("BUTTON");
var t = document.createTextNode("Press to start recording");

my_btn.appendChild(t);
//my_p.appendChild(my_btn);
my_div.appendChild(my_btn);
document.body.appendChild(my_div);

var base64data = 0;
var reader;
var recorder, gumStream;
var recordButton = my_btn;

var handleSuccess = function(stream) {
  gumStream = stream;
  var options = {
    //bitsPerSecond: 8000, //chrome seems to ignore, always 48k
    mimeType : 'audio/webm;codecs=opus'
    //mimeType : 'audio/webm;codecs=pcm'
  };
  //recorder = new MediaRecorder(stream, options);
  recorder = new MediaRecorder(stream);
  recorder.ondataavailable = function(e) {
    var url = URL.createObjectURL(e.data);
    var preview = document.createElement('audio');
    preview.controls = true;
    preview.src = url;
    document.body.appendChild(preview);

    reader = new FileReader();
    reader.readAsDataURL(e.data);
    reader.onloadend = function() {
      base64data = reader.result;
      //console.log("Inside FileReader:" + base64data);
    }
  };
  recorder.start();
  };

recordButton.innerText = "Recording... press to stop";

navigator.mediaDevices.getUserMedia({audio: true}).then(handleSuccess);


function toggleRecording() {
  if (recorder && recorder.state == "recording") {
      recorder.stop();
      gumStream.getAudioTracks()[0].stop();
      recordButton.innerText = "Saving the recording... pls wait!"
  }
}

// https://stackoverflow.com/a/951057
function sleep(ms) {
  return new Promise(resolve => setTimeout(resolve, ms));
}

var data = new Promise(resolve=>{
//recordButton.addEventListener("click", toggleRecording);
recordButton.onclick = ()=>{
toggleRecording()

sleep(2000).then(() => {
  // wait 2000ms for the data to be available...
  // ideally this should use something like await...
  //console.log("Inside data:" + base64data)
  resolve(base64data.toString())

});

}
});

</script>
"""

def get_audio():
  display(HTML(AUDIO_HTML))
  data = eval_js("data")
  binary = b64decode(data.split(',')[1])

  process = (ffmpeg
    .input('pipe:0')
    .output('pipe:1', format='wav')
    .run_async(pipe_stdin=True, pipe_stdout=True, pipe_stderr=True, quiet=True, overwrite_output=True)
  )
  output, err = process.communicate(input=binary)

  riff_chunk_size = len(output) - 8
  # Break up the chunk size into four bytes, held in b.
  q = riff_chunk_size
  b = []
  for i in range(4):
      q, r = divmod(q, 256)
      b.append(r)

  # Replace bytes 4:8 in proc.stdout with the actual size of the RIFF chunk.
  riff = output[:4] + bytes(b) + output[8:]

  sr, audio = wav_read(io.BytesIO(riff))

  return audio, sr

# %%
audio, sr = get_audio()

# %%
from scipy.io import wavfile
wavfile.write("my_audio.wav", sr, audio)
